# %% [markdown]
# # Characteristics of Businesses - Group Exercise

# %%
import pandas as pd
import requests

tech_variables = 'https://api.census.gov/data/2018/abstcb/variables.html'
owner_variables = 'https://api.census.gov/data/2018/abscbo/variables.html'
characteristics_variables = 'https://api.census.gov/data/2018/abscb/variables.html'
company_summary_variables = 'https://api.census.gov/data/2018/abscs/variables.html'

# %%
tech_vars = pd.read_html(tech_variables)
owner_vars = pd.read_html(owner_variables)
characteristic_vars = pd.read_html(characteristics_variables)
company_summary_vars = pd.read_html(company_summary_variables)

variable_data_frame = [tech_vars, owner_vars, characteristic_vars, company_summary_vars]

for frame in variable_data_frame:
    print(", ".join(frame[0].columns.tolist()))
# Out:
# [               Name                                              Label  \
# 0               EMP                                Number of employees
# 1           EMP_PCT                           Percent of employees (%)
# 2         EMP_PCT_S         Standard error of percent of employees (%)
# 3             EMP_S  Relative standard error of number of employees...
# 4         ETH_GROUP                                     Ethnicity code
# 5         FACTORS_P  Factors adversely affecting technology product...
# 6         FACTORS_U    Factors adversely affecting technology use code
# 7         FIRMPDEMP                           Number of employer firms
# 8     FIRMPDEMP_PCT                      Percent of employer firms (%)
# 9   FIRMPDEMP_PCT_S    Standard error of percent of employer firms (%)
# 10      FIRMPDEMP_S      Relative standard error of employer firms (%)
# 11              for                       Census API FIPS 'for' clause
# ...

# %%
cols_to_keep = ['Name','Label','Attributes','Predicate Type','Group']
table = table[[_ for _ in table.columns if _ in cols_to_keep]]

table = table[[_ for _ in table.columns[:2]]]

# %%
table
# Out:
#             Name                                              Label
# 0           CBSA                                          Geography
# 1            EMP                                Number of employees
# 2          EMP_S  Relative standard error of number of employees...
# 3        EMPSZFI                      Employment size of firms code
# 4      ETH_GROUP                                     Ethnicity code
# 5      FIRMPDEMP                           Number of employer firms
# 6    FIRMPDEMP_S      Relative standard error of employer firms (%)
# 7            for                       Census API FIPS 'for' clause
# 8         GEO_ID                         Geographic identifier code
# 9        GEOCOMP                                   GEO_ID Component
# 10            in                        Census API FIPS 'in' clause
# 11     NAICS2017                                    2017 NAICS code
# 12        NATION                                          Geography
# ...

# %%
interest_vars = ",".join(_ for _ in list(set(table.Name.tolist())) if _ not in ['for','in','ucgid','26 variables'])
print(interest_vars)
# Out:
# STATE,NAICS2017,RCPPDEMP,CBSA,NATION,RACE_GROUP,SEX,SUMLEVEL,ETH_GROUP,EMP,RCPPDEMP_S,GEO_ID,PAYANN_S,PAYANN,EMP_S,GEOCOMP,VET_GROUP,YIBSZFI,RCPSZFI,FIRMPDEMP_S,FIRMPDEMP,YEAR,EMPSZFI

# %%
tech_path = 'https://api.census.gov/data/2019/absc'
end_point = 'b0?get=&for=us'
complete_path = data_path + interest_vars + end_point
print(complete_path)
# Out:
# https://api.census.gov/data/2019/abscb?get=STATE,NAICS2017,RCPPDEMP,CBSA,NATION,RACE_GROUP,SEX,SUMLEVEL,ETH_GROUP,EMP,RCPPDEMP_S,GEO_ID,PAYANN_S,PAYANN,EMP_S,GEOCOMP,VET_GROUP,YIBSZFI,RCPSZFI,FIRMPDEMP_S,FIRMPDEMP,YEAR,EMPSZFI&for=us
